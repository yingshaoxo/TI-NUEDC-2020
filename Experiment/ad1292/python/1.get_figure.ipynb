# %%
import pandas as pd

# %%
table = pd.read_excel('on body.xlsx', index_col=0)

# %%
table
# Out:
#         ecg     a    b1  b2   c1  c2  c3  c4  hear_rate    ECG  ...    B1  B2  \
# 0    -23295  2839  2839   0   23  11   0   0          0  42241  ...  2839   0
# 1     13057  2857  2857   0   41  11   0   0          0  13057  ...  2857   0
# 2    -21503  2883  2883   0   67  11   0   0          0  44033  ...  2883   0
# 3     20225  2864  2864   0   48  11   0   0          0  20225  ...  2864   0
# 4     28417  2893  2893   0   77  11   0   0          0  28417  ...  2893   0
# ...     ...   ...   ...  ..  ...  ..  ..  ..        ...    ...  ...   ...  ..
# 4183  13568  2861  2861   0   45  11   0   0          0  13568  ...  2861   0
# 4184 -16129  2940  2940   0  124  11   0   0          0  49407  ...  2940   0
# 4185   -512  2851  2851   0   35  11   0   0          0  65024  ...  2851   0
# 4186 -21760  2875  2875   0   59  11   0   0          0  43776  ...  2875   0
# 4187  25343  2926  2926   0  110  11   0   0          0  25343  ...  2926   0
#
#        C1  C2  C3  C4  HEAR_RATE       float_c  float_c1  float_c2
# 0      23  11   0   0          0  3.978286e-42  0.000216       0.0
# 1      41  11   0   0          0  4.003510e-42  0.000219       0.0
# 2      67  11   0   0          0  4.039943e-42  0.000222       0.0
# 3      48  11   0   0          0  4.013319e-42  0.000219       0.0
# 4      77  11   0   0          0  4.053956e-42  0.000223       0.0
# ...   ...  ..  ..  ..        ...           ...       ...       ...
# 4183   45  11   0   0          0  4.009115e-42  0.000219       0.0
# 4184  124  11   0   0          0  4.119817e-42  0.000228       0.0
# 4185   35  11   0   0          0  3.995102e-42  0.000218       0.0
# 4186   59  11   0   0          0  4.028733e-42  0.000221       0.0
# 4187  110  11   0   0          0  4.100199e-42  0.000227       0.0
#
# [4188 rows x 21 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, figure_parts = plt.subplots(4, 6)
fig.suptitle('on body')

for index, column_title in enumerate(table.columns.to_list()):
    column = table[[column_title]].to_numpy()
    
    x = np.arange(0, column.shape[0]) 
    y = column
    
    ax = figure_parts[index//6][index%6]
    ax.set_xlabel(column_title)
    ax.plot(x, y)
    
fig.set_size_inches(26, 16)
plt.savefig('On body.png',dpi=100, bbox_inches='tight' )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 360)
y = np.sin(np.radians(x))

plt.plot(x, y)
plt.savefig("sine wave.png", dpi=100)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, figure_parts = plt.subplots(3, 2)
fig.suptitle('yingshaoxo: This is life')

degree = 0

for index in range(3 * 2):
    random_num = np.random.randint(180, 360, size=1)[0]
    
    x = np.arange(degree, degree + random_num) 
    y = np.sin(np.radians(x))
    degree += random_num
    
    ax = figure_parts[index//2][index%2]
    ax.set_xlabel(str(index))
    ax.plot(x, y)
    
fig.set_size_inches(19, 12)
plt.savefig('this is life.png', dpi=100, bbox_inches='tight' )
plt.show()

# %%
360/2
# Out:
# 180.0
